# %%
import sys
import collections
import itertools
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mode
from scipy.spatial.distance import squareform

plt.style.use('bmh')
# %matplotlib inline

try:
    from IPython.display import clear_output
    have_ipython = True
except ImportError:
    have_ipython = False

class KnnDtw(object):
    """K-nearest neighbor classifier using dynamic time warping
    as the distance measure between pairs of time series arrays
    
    Arguments
    ---------
    n_neighbors : int, optional (default = 5)
        Number of neighbors to use by default for KNN
        
    max_warping_window : int, optional (default = infinity)
        Maximum warping window allowed by the DTW dynamic
        programming function
            
    subsample_step : int, optional (default = 1)
        Step size for the timeseries array. By setting subsample_step = 2,
        the timeseries length will be reduced by 50% because every second
        item is skipped. Implemented by x[:, ::subsample_step]
    """
    
    def __init__(self, n_neighbors=5, max_warping_window=10000, subsample_step=1):
        self.n_neighbors = n_neighbors
        self.max_warping_window = max_warping_window
        self.subsample_step = subsample_step
    
    def fit(self, x, l):
        """Fit the model using x as training data and l as class labels
        
        Arguments
        ---------
        x : array of shape [n_samples, n_timepoints]
            Training data set for input into KNN classifer
            
        l : array of shape [n_samples]
            Training labels for input into KNN classifier
        """
        
        self.x = x
        self.l = l
        
    def _dtw_distance(self, ts_a, ts_b, d = lambda x,y: abs(x-y)):
        """Returns the DTW similarity distance between two 2-D
        timeseries numpy arrays.

        Arguments
        ---------
        ts_a, ts_b : array of shape [n_samples, n_timepoints]
            Two arrays containing n_samples of timeseries data
            whose DTW distance between each sample of A and B
            will be compared
        
        d : DistanceMetric object (default = abs(x-y))
            the distance measure used for A_i - B_j in the
            DTW dynamic programming function
        
        Returns
        -------
        DTW distance between A and B
        """

        # Create cost matrix via broadcasting with large int
        ts_a, ts_b = np.array(ts_a), np.array(ts_b)
        M, N = len(ts_a), len(ts_b)
        cost = sys.maxsize * np.ones((M, N))

        # Initialize the first row and column
        cost[0, 0] = d(ts_a[0], ts_b[0])
        for i in range(1, M):
            cost[i, 0] = cost[i-1, 0] + d(ts_a[i], ts_b[0])

        for j in range(1, N):
            cost[0, j] = cost[0, j-1] + d(ts_a[0], ts_b[j])

        # Populate rest of cost matrix within window
        for i in range(1, M):
            for j in range(max(1, i - self.max_warping_window),
                            min(N, i + self.max_warping_window)):
                choices = cost[i - 1, j - 1], cost[i, j-1], cost[i-1, j]
                cost[i, j] = min(choices) + d(ts_a[i], ts_b[j])

        # Return DTW distance given window 
        return cost[-1, -1]
    
    def _dist_matrix(self, x, y):
        """Computes the M x N distance matrix between the training
        dataset and testing dataset (y) using the DTW distance measure
        
        Arguments
        ---------
        x : array of shape [n_samples, n_timepoints]
        
        y : array of shape [n_samples, n_timepoints]
        
        Returns
        -------
        Distance matrix between each item of x and y with
            shape [training_n_samples, testing_n_samples]
        """
        
        # Compute the distance matrix        
        dm_count = 0
        
        # Compute condensed distance matrix (upper triangle) of pairwise dtw distances
        # when x and y are the same array
        if(np.array_equal(x, y)):
            x_s = np.shape(x)
            dm = np.zeros((x_s[0] * (x_s[0] - 1)) // 2, dtype=np.double)
            
            p = ProgressBar(shape(dm)[0])
            
            for i in range(0, x_s[0] - 1):
                for j in range(i + 1, x_s[0]):
                    dm[dm_count] = self._dtw_distance(x[i, ::self.subsample_step],
                                                      y[j, ::self.subsample_step])
                    
                    dm_count += 1
                    p.animate(dm_count)
            
            # Convert to squareform
            dm = squareform(dm)
            return dm
        
        # Compute full distance matrix of dtw distnces between x and y
        else:
            x_s = np.shape(x)
            y_s = np.shape(y)
            dm = np.zeros((x_s[0], y_s[0])) 
            dm_size = x_s[0]*y_s[0]
            
            p = ProgressBar(dm_size)
        
            for i in range(0, x_s[0]):
                for j in range(0, y_s[0]):
                    dm[i, j] = self._dtw_distance(x[i, ::self.subsample_step],
                                                  y[j, ::self.subsample_step])
                    # Update progress bar
                    dm_count += 1
                    p.animate(dm_count)
        
            return dm
        
    def predict(self, x):
        """Predict the class labels or probability estimates for 
        the provided data

        Arguments
        ---------
          x : array of shape [n_samples, n_timepoints]
              Array containing the testing data set to be classified
          
        Returns
        -------
          2 arrays representing:
              (1) the predicted class labels 
              (2) the knn label count probability
        """
        
        dm = self._dist_matrix(x, self.x)

        # Identify the k nearest neighbors
        knn_idx = dm.argsort()[:, :self.n_neighbors]

        # Identify k nearest labels
        knn_labels = self.l[knn_idx]
        
        # Model Label
        mode_data = mode(knn_labels, axis=1)
        mode_label = mode_data[0]
        mode_proba = mode_data[1]/self.n_neighbors

        return mode_label.ravel(), mode_proba.ravel()

class ProgressBar:
    """This progress bar was taken from PYMC
    """
    def __init__(self, iterations):
        self.iterations = iterations
        self.prog_bar = '[]'
        self.fill_char = '*'
        self.width = 40
        self.__update_amount(0)
        if have_ipython:
            self.animate = self.animate_ipython
        else:
            self.animate = self.animate_noipython

    def animate_ipython(self, iter):
        print ('\r', self,
        sys.stdout.flush())
        self.update_iteration(iter + 1)

    def update_iteration(self, elapsed_iter):
        self.__update_amount((elapsed_iter / float(self.iterations)) * 100.0)
        self.prog_bar += '  %d of %s complete' % (elapsed_iter, self.iterations)

    def __update_amount(self, new_amount):
        percent_done = int(round((new_amount / 100.0) * 100.0))
        all_full = self.width - 2
        num_hashes = int(round((percent_done / 100.0) * all_full))
        self.prog_bar = '[' + self.fill_char * num_hashes + ' ' * (all_full - num_hashes) + ']'
        pct_place = (len(self.prog_bar) // 2) - len(str(percent_done))
        pct_string = '%d%%' % percent_done
        self.prog_bar = self.prog_bar[0:pct_place] + \
            (pct_string + self.prog_bar[pct_place + len(pct_string):])

    def __str__(self):
        return str(self.prog_bar)

# %% [markdown]
# Measuring DTW distance

# %%
time = np.linspace(0,20,1000)
amplitude_a = 5*np.sin(time)
amplitude_b = 3*np.sin(time + 1)

m = KnnDtw()
distance = m._dtw_distance(amplitude_a, amplitude_b)

fig = plt.figure(figsize=(12,4))
_ = plt.plot(time, amplitude_a, label='A')
_ = plt.plot(time, amplitude_b, label='B')
_ = plt.title('DTW distance between A and B is %.2f' % distance)
_ = plt.ylabel('Amplitude')
_ = plt.xlabel('Time')
_ = plt.legend()

# %%
# Import the HAR dataset
x_train_file = open('UCI HAR Dataset/train/Inertial Signals/body_acc_z_train.txt', 'r')
y_train_file = open('UCI HAR Dataset/train/y_train.txt', 'r')

x_test_file = open('UCI HAR Dataset/test/Inertial Signals/body_acc_z_test.txt', 'r')
y_test_file = open('UCI HAR Dataset/test/y_test.txt', 'r')

# Create empty lists
x_train = []
y_train = []
x_test = []
y_test = []

# Mapping table for classes
labels = {1:'WALKING', 2:'WALKING UPSTAIRS', 3:'WALKING DOWNSTAIRS',
          4:'SITTING', 5:'STANDING', 6:'LAYING'}

# Loop through datasets
for x in x_train_file:
    x_train.append([float(ts) for ts in x.split()])
    
for y in y_train_file:
    y_train.append(int(y.rstrip('\n')))
    
for x in x_test_file:
    x_test.append([float(ts) for ts in x.split()])
    
for y in y_test_file:
    y_test.append(int(y.rstrip('\n')))
    
# Convert to numpy for efficiency
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
print(x_train.shape)
# Out:
# (7352, 128)

# %%
plt.figure(figsize=(11,7))
colors = ['#D62728','#2C9F2C','#FD7F23','#1F77B4','#9467BD',
          '#8C564A','#7F7F7F','#1FBECF','#E377C2','#BCBD27']

for i, r in enumerate([0,27,65,100,145,172]):
    plt.subplot(3,2,i+1)
    plt.plot(x_train[r][:1000], label=labels[y_train[r]], color=colors[i], linewidth=2)
    plt.xlabel('Samples @50Hz')
    plt.legend(loc='upper left')
    plt.tight_layout()

# %%
plt.figure
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
x_train[0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aikyn\Desktop\work\НИР\Classification methods\DTW.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aikyn/Desktop/work/%D0%9D%D0%98%D0%A0/Classification%20methods/DTW.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> x_train[0].shape
#
# NameError: name 'x_train' is not defined

# %%
num = 40
m = KnnDtw(n_neighbors=1, max_warping_window=10)
m.fit(x_train[::num], y_train[::num])
label, proba = m.predict(x_test[::num])
# Out:
#  [                  0%                  ] None
#  [                  0%                  ]  2 of 13616 complete None
#  [                  0%                  ]  3 of 13616 complete None
#  [                  0%                  ]  4 of 13616 complete None
#  [                  0%                  ]  5 of 13616 complete None
#  [                  0%                  ]  6 of 13616 complete None
#  [                  0%                  ]  7 of 13616 complete None
#  [                  0%                  ]  8 of 13616 complete None
#  [                  0%                  ]  9 of 13616 complete None
#  [                  0%                  ]  10 of 13616 complete None
#  [                  0%                  ]  11 of 13616 complete None
#  [                  0%                  ]  12 of 13616 complete None
#  [                  0%                  ]  13 of 13616 complete None
#  [                  0%                  ]  14 of 13616 complete None
#  [                  0%                  ]  15 of 13616 complete None
#  [                  0%                  ]  16 of 13616 complete None
#  [                  0%                  ]  17 of 13616 complete None
#  [                  0%                  ]  18 of 13616 complete None
#  [                  0%                  ]  19 of 13616 complete None
#  [                  0%                  ]  20 of 13616 complete None
#  [                  0%                  ]  21 of 13616 complete None
#  [                  0%                  ]  22 of 13616 complete None
#  [                  0%                  ]  23 of 13616 complete None
#  [                  0%                  ]  24 of 13616 complete None
#  [                  0%                  ]  25 of 13616 complete None
#  [                  0%                  ]  26 of 13616 complete None
#  [                  0%                  ]  27 of 13616 complete None
#  [                  0%                  ]  28 of 13616 complete None
#  [                  0%                  ]  29 of 13616 complete None
#  [                  0%                  ]  30 of 13616 complete None
#  [                  0%                  ]  31 of 13616 complete None
#  [                  0%                  ]  32 of 13616 complete None
#  [                  0%                  ]  33 of 13616 complete None
#  [                  0%                  ]  34 of 13616 complete None
#  [                  0%                  ]  35 of 13616 complete None
#  [                  0%                  ]  36 of 13616 complete None
#  [                  0%                  ]  37 of 13616 complete None
#  [                  0%                  ]  38 of 13616 complete None
#  [                  0%                  ]  39 of 13616 complete None
#  [                  0%                  ]  40 of 13616 complete None
#  [                  0%                  ]  41 of 13616 complete None
#  [                  0%                  ]  42 of 13616 complete None
#  [                  0%                  ]  43 of 13616 complete None
#  [                  0%                  ]  44 of 13616 complete None
#  [                  0%                  ]  45 of 13616 complete None
#  [                  0%                  ]  46 of 13616 complete None
#  [                  0%                  ]  47 of 13616 complete None
#  [                  0%                  ]  48 of 13616 complete None
#  [                  0%                  ]  49 of 13616 complete None
#  [                  0%                  ]  50 of 13616 complete None
#  [                  0%                  ]  51 of 13616 complete None
#  [                  0%                  ]  52 of 13616 complete None
#  [                  0%                  ]  53 of 13616 complete None
#  [                  0%                  ]  54 of 13616 complete None
#  [                  0%                  ]  55 of 13616 complete None
#  [                  0%                  ]  56 of 13616 complete None
#  [                  0%                  ]  57 of 13616 complete None
#  [                  0%                  ]  58 of 13616 complete None
#  [                  0%                  ]  59 of 13616 complete None
#  [                  0%                  ]  60 of 13616 complete None
#  [                  0%                  ]  61 of 13616 complete None
#  [                  0%                  ]  62 of 13616 complete None
#  [                  0%                  ]  63 of 13616 complete None
#  [                  0%                  ]  64 of 13616 complete None
#  [                  0%                  ]  65 of 13616 complete None
#  [                  0%                  ]  66 of 13616 complete None
#  [                  0%                  ]  67 of 13616 complete None
#  [                  0%                  ]  68 of 13616 complete None
#  [                  1%                  ]  69 of 13616 complete None
#  [                  1%                  ]  70 of 13616 complete None
#  [                  1%                  ]  71 of 13616 complete None
#  [                  1%                  ]  72 of 13616 complete None
#  [                  1%                  ]  73 of 13616 complete None
#  [                  1%                  ]  74 of 13616 complete None
#  [                  1%                  ]  75 of 13616 complete None
#  [                  1%                  ]  76 of 13616 complete None
#  [                  1%                  ]  77 of 13616 complete None
#  [                  1%                  ]  78 of 13616 complete None
#  [                  1%                  ]  79 of 13616 complete None
#  [                  1%                  ]  80 of 13616 complete None
#  [                  1%                  ]  81 of 13616 complete None
#  [                  1%                  ]  82 of 13616 complete None
#  [                  1%                  ]  83 of 13616 complete None
#  [                  1%                  ]  84 of 13616 complete None
#  [                  1%                  ]  85 of 13616 complete None
#  [                  1%                  ]  86 of 13616 complete None
#  [                  1%                  ]  87 of 13616 complete None
#  [                  1%                  ]  88 of 13616 complete None
#  [                  1%                  ]  89 of 13616 complete None
#  [                  1%                  ]  90 of 13616 complete None
#  [                  1%                  ]  91 of 13616 complete None
#  [                  1%                  ]  92 of 13616 complete None
#  [                  1%                  ]  93 of 13616 complete None
#  [                  1%                  ]  94 of 13616 complete None
#  [                  1%                  ]  95 of 13616 complete None
#  [                  1%                  ]  96 of 13616 complete None
#  [                  1%                  ]  97 of 13616 complete None
#  [                  1%                  ]  98 of 13616 complete None
#  [                  1%                  ]  99 of 13616 complete None
#  [                  1%                  ]  100 of 13616 complete None
#  [                  1%                  ]  101 of 13616 complete None
#  [                  1%                  ]  102 of 13616 complete None
#  [                  1%                  ]  103 of 13616 complete None
#  [                  1%                  ]  104 of 13616 complete None
#  [                  1%                  ]  105 of 13616 complete None
#  [                  1%                  ]  106 of 13616 complete None
#  [                  1%                  ]  107 of 13616 complete None
#  [                  1%                  ]  108 of 13616 complete None
#  [                  1%                  ]  109 of 13616 complete None
#  [                  1%                  ]  110 of 13616 complete None
#  [                  1%                  ]  111 of 13616 complete None
#  [                  1%                  ]  112 of 13616 complete None
#  [                  1%                  ]  113 of 13616 complete None
#  [                  1%                  ]  114 of 13616 complete None
#  [                  1%                  ]  115 of 13616 complete None
#  [                  1%                  ]  116 of 13616 complete None
#  [                  1%                  ]  117 of 13616 complete None
#  [                  1%                  ]  118 of 13616 complete None
#  [                  1%                  ]  119 of 13616 complete None
#  [                  1%                  ]  120 of 13616 complete None
#  [                  1%                  ]  121 of 13616 complete None
#  [                  1%                  ]  122 of 13616 complete None
#  [                  1%                  ]  123 of 13616 complete None
#  [                  1%                  ]  124 of 13616 complete None
#  [                  1%                  ]  125 of 13616 complete None
#  [                  1%                  ]  126 of 13616 complete None
#  [                  1%                  ]  127 of 13616 complete None
#  [                  1%                  ]  128 of 13616 complete None
#  [                  1%                  ]  129 of 13616 complete None
#  [                  1%                  ]  130 of 13616 complete None
#  [                  1%                  ]  131 of 13616 complete None
#  [                  1%                  ]  132 of 13616 complete None
#  [                  1%                  ]  133 of 13616 complete None
#  [                  1%                  ]  134 of 13616 complete None
#  [                  1%                  ]  135 of 13616 complete None
#  [                  1%                  ]  136 of 13616 complete None
#  [                  1%                  ]  137 of 13616 complete None
#  [                  1%                  ]  138 of 13616 complete None
#  [                  1%                  ]  139 of 13616 complete None
#  [                  1%                  ]  140 of 13616 complete None
#  [                  1%                  ]  141 of 13616 complete None
#  [                  1%                  ]  142 of 13616 complete None
#  [                  1%                  ]  143 of 13616 complete None
#  [                  1%                  ]  144 of 13616 complete None
#  [                  1%                  ]  145 of 13616 complete None
#  [                  1%                  ]  146 of 13616 complete None
#  [                  1%                  ]  147 of 13616 complete None
#  [                  1%                  ]  148 of 13616 complete None
#  [                  1%                  ]  149 of 13616 complete None
#  [                  1%                  ]  150 of 13616 complete None
#  [                  1%                  ]  151 of 13616 complete None
#  [                  1%                  ]  152 of 13616 complete None
#  [                  1%                  ]  153 of 13616 complete None
#  [                  1%                  ]  154 of 13616 complete None
#  [                  1%                  ]  155 of 13616 complete None
#  [                  1%                  ]  156 of 13616 complete None
#  [                  1%                  ]  157 of 13616 complete None
#  [                  1%                  ]  158 of 13616 complete None
#  [                  1%                  ]  159 of 13616 complete None
#  [                  1%                  ]  160 of 13616 complete None
#  [                  1%                  ]  161 of 13616 complete None
#  [                  1%                  ]  162 of 13616 complete None
#  [                  1%                  ]  163 of 13616 complete None
#  [                  1%                  ]  164 of 13616 complete None
#  [                  1%                  ]  165 of 13616 complete None
#  [                  1%                  ]  166 of 13616 complete None
#  [                  1%                  ]  167 of 13616 complete None
#  [                  1%                  ]  168 of 13616 complete None
#  [                  1%                  ]  169 of 13616 complete None
#  [                  1%                  ]  170 of 13616 complete None
#  [                  1%                  ]  171 of 13616 complete None
#  [                  1%                  ]  172 of 13616 complete None
#  [                  1%                  ]  173 of 13616 complete None
#  [                  1%                  ]  174 of 13616 complete None
#  [                  1%                  ]  175 of 13616 complete None
#  [                  1%                  ]  176 of 13616 complete None
#  [                  1%                  ]  177 of 13616 complete None
#  [                  1%                  ]  178 of 13616 complete None
#  [                  1%                  ]  179 of 13616 complete None
#  [                  1%                  ]  180 of 13616 complete None
#  [                  1%                  ]  181 of 13616 complete None
#  [                  1%                  ]  182 of 13616 complete None
#  [                  1%                  ]  183 of 13616 complete None
#  [                  1%                  ]  184 of 13616 complete None
#  [                  1%                  ]  185 of 13616 complete None
#  [                  1%                  ]  186 of 13616 complete None
#  [                  1%                  ]  187 of 13616 complete None
#  [                  1%                  ]  188 of 13616 complete None
#  [                  1%                  ]  189 of 13616 complete None
#  [                  1%                  ]  190 of 13616 complete None
#  [                  1%                  ]  191 of 13616 complete None
#  [                  1%                  ]  192 of 13616 complete None
#  [                  1%                  ]  193 of 13616 complete None
#  [                  1%                  ]  194 of 13616 complete None
#  [                  1%                  ]  195 of 13616 complete None
#  [                  1%                  ]  196 of 13616 complete None
#  [                  1%                  ]  197 of 13616 complete None
#  [                  1%                  ]  198 of 13616 complete None
#  [                  1%                  ]  199 of 13616 complete None
#  [                  1%                  ]  200 of 13616 complete None
#  [                  1%                  ]  201 of 13616 complete None
#  [                  1%                  ]  202 of 13616 complete None
#  [                  1%                  ]  203 of 13616 complete None
#  [                  1%                  ]  204 of 13616 complete None
#  [*                 2%                  ]  205 of 13616 complete None
#  [*                 2%                  ]  206 of 13616 complete None
#  [*                 2%                  ]  207 of 13616 complete None
#  [*                 2%                  ]  208 of 13616 complete None
#  [*                 2%                  ]  209 of 13616 complete None
#  [*                 2%                  ]  210 of 13616 complete None
#  [*                 2%                  ]  211 of 13616 complete None
#  [*                 2%                  ]  212 of 13616 complete None
#  [*                 2%                  ]  213 of 13616 complete None
#  [*                 2%                  ]  214 of 13616 complete None
#  [*                 2%                  ]  215 of 13616 complete None
#  [*                 2%                  ]  216 of 13616 complete None
#  [*                 2%                  ]  217 of 13616 complete None
#  [*                 2%                  ]  218 of 13616 complete None
#  [*                 2%                  ]  219 of 13616 complete None
#  [*                 2%                  ]  220 of 13616 complete None
#  [*                 2%                  ]  221 of 13616 complete None
#  [*                 2%                  ]  222 of 13616 complete None
#  [*                 2%                  ]  223 of 13616 complete None
#  [*                 2%                  ]  224 of 13616 complete None
#  [*                 2%                  ]  225 of 13616 complete None
#  [*                 2%                  ]  226 of 13616 complete None
#  [*                 2%                  ]  227 of 13616 complete None
#  [*                 2%                  ]  228 of 13616 complete None
#  [*                 2%                  ]  229 of 13616 complete None
#  [*                 2%                  ]  230 of 13616 complete None
#  [*                 2%                  ]  231 of 13616 complete None
#  [*                 2%                  ]  232 of 13616 complete None
#  [*                 2%                  ]  233 of 13616 complete None
#  [*                 2%                  ]  234 of 13616 complete None
#  [*                 2%                  ]  235 of 13616 complete None
#  [*                 2%                  ]  236 of 13616 complete None
#  [*                 2%                  ]  237 of 13616 complete None
#  [*                 2%                  ]  238 of 13616 complete None
#  [*                 2%                  ]  239 of 13616 complete None
#  [*                 2%                  ]  240 of 13616 complete None
#  [*                 2%                  ]  241 of 13616 complete None
#  [*                 2%                  ]  242 of 13616 complete None
#  [*                 2%                  ]  243 of 13616 complete None
#  [*                 2%                  ]  244 of 13616 complete None
#  [*                 2%                  ]  245 of 13616 complete None
#  [*                 2%                  ]  246 of 13616 complete None
#  [*                 2%                  ]  247 of 13616 complete None
#  [*                 2%                  ]  248 of 13616 complete None
#  [*                 2%                  ]  249 of 13616 complete None
#  [*                 2%                  ]  250 of 13616 complete None
#  [*                 2%                  ]  251 of 13616 complete None
#  [*                 2%                  ]  252 of 13616 complete None
#  [*                 2%                  ]  253 of 13616 complete None
#  [*                 2%                  ]  254 of 13616 complete None
#  [*                 2%                  ]  255 of 13616 complete None
#  [*                 2%                  ]  256 of 13616 complete None
#  [*                 2%                  ]  257 of 13616 complete None
#  [*                 2%                  ]  258 of 13616 complete None
#  [*                 2%                  ]  259 of 13616 complete None
#  [*                 2%                  ]  260 of 13616 complete None
#  [*                 2%                  ]  261 of 13616 complete None
#  [*                 2%                  ]  262 of 13616 complete None
#  [*                 2%                  ]  263 of 13616 complete None
#  [*                 2%                  ]  264 of 13616 complete None
#  [*                 2%                  ]  265 of 13616 complete None
#  [*                 2%                  ]  266 of 13616 complete None
#  [*                 2%                  ]  267 of 13616 complete None
#  [*                 2%                  ]  268 of 13616 complete None
#  [*                 2%                  ]  269 of 13616 complete None
#  [*                 2%                  ]  270 of 13616 complete None
#  [*                 2%                  ]  271 of 13616 complete None
#  [*                 2%                  ]  272 of 13616 complete None
#  [*                 2%                  ]  273 of 13616 complete None
#  [*                 2%                  ]  274 of 13616 complete None
#  [*                 2%                  ]  275 of 13616 complete None
#  [*                 2%                  ]  276 of 13616 complete None
#  [*                 2%                  ]  277 of 13616 complete None
#  [*                 2%                  ]  278 of 13616 complete None
#  [*                 2%                  ]  279 of 13616 complete None
#  [*                 2%                  ]  280 of 13616 complete None
#  [*                 2%                  ]  281 of 13616 complete None
#  [*                 2%                  ]  282 of 13616 complete None
#  [*                 2%                  ]  283 of 13616 complete None
#  [*                 2%                  ]  284 of 13616 complete None
#  [*                 2%                  ]  285 of 13616 complete None
#  [*                 2%                  ]  286 of 13616 complete None
#  [*                 2%                  ]  287 of 13616 complete None
#  [*                 2%                  ]  288 of 13616 complete None
#  [*                 2%                  ]  289 of 13616 complete None
#  [*                 2%                  ]  290 of 13616 complete None
#  [*                 2%                  ]  291 of 13616 complete None
#  [*                 2%                  ]  292 of 13616 complete None
#  [*                 2%                  ]  293 of 13616 complete None
#  [*                 2%                  ]  294 of 13616 complete None
#  [*                 2%                  ]  295 of 13616 complete None
#  [*                 2%                  ]  296 of 13616 complete None
#  [*                 2%                  ]  297 of 13616 complete None
#  [*                 2%                  ]  298 of 13616 complete None
#  [*                 2%                  ]  299 of 13616 complete None
#  [*                 2%                  ]  300 of 13616 complete None
#  [*                 2%                  ]  301 of 13616 complete None
#  [*                 2%                  ]  302 of 13616 complete None
#  [*                 2%                  ]  303 of 13616 complete None
#  [*                 2%                  ]  304 of 13616 complete None
#  [*                 2%                  ]  305 of 13616 complete None
#  [*                 2%                  ]  306 of 13616 complete None
#  [*                 2%                  ]  307 of 13616 complete None
#  [*                 2%                  ]  308 of 13616 complete None
#  [*                 2%                  ]  309 of 13616 complete None
#  [*                 2%                  ]  310 of 13616 complete None
#  [*                 2%                  ]  311 of 13616 complete None
#  [*                 2%                  ]  312 of 13616 complete None
#  [*                 2%                  ]  313 of 13616 complete None
#  [*                 2%                  ]  314 of 13616 complete None
#  [*                 2%                  ]  315 of 13616 complete None
#  [*                 2%                  ]  316 of 13616 complete None
#  [*                 2%                  ]  317 of 13616 complete None
#  [*                 2%                  ]  318 of 13616 complete None
#  [*                 2%                  ]  319 of 13616 complete None
#  [*                 2%                  ]  320 of 13616 complete None
#  [*                 2%                  ]  321 of 13616 complete None
#  [*                 2%                  ]  322 of 13616 complete None
#  [*                 2%                  ]  323 of 13616 complete None
#  [*                 2%                  ]  324 of 13616 complete None
#  [*                 2%                  ]  325 of 13616 complete None
#  [*                 2%                  ]  326 of 13616 complete None
#  [*                 2%                  ]  327 of 13616 complete None
#  [*                 2%                  ]  328 of 13616 complete None
#  [*                 2%                  ]  329 of 13616 complete None
#  [*                 2%                  ]  330 of 13616 complete None
#  [*                 2%                  ]  331 of 13616 complete None
#  [*                 2%                  ]  332 of 13616 complete None
#  [*                 2%                  ]  333 of 13616 complete None
#  [*                 2%                  ]  334 of 13616 complete None
#  [*                 2%                  ]  335 of 13616 complete None
#  [*                 2%                  ]  336 of 13616 complete None
#  [*                 2%                  ]  337 of 13616 complete None
#  [*                 2%                  ]  338 of 13616 complete None
#  [*                 2%                  ]  339 of 13616 complete None
#  [*                 2%                  ]  340 of 13616 complete None
#  [*                 3%                  ]  341 of 13616 complete None
#  [*                 3%                  ]  342 of 13616 complete None
#  [*                 3%                  ]  343 of 13616 complete None
#  [*                 3%                  ]  344 of 13616 complete None
#  [*                 3%                  ]  345 of 13616 complete None
#  [*                 3%                  ]  346 of 13616 complete None
#  [*                 3%                  ]  347 of 13616 complete None
#  [*                 3%                  ]  348 of 13616 complete None
#  [*                 3%                  ]  349 of 13616 complete None
#  [*                 3%                  ]  350 of 13616 complete None
#  [*                 3%                  ]  351 of 13616 complete None
#  [*                 3%                  ]  352 of 13616 complete None
#  [*                 3%                  ]  353 of 13616 complete None
#  [*                 3%                  ]  354 of 13616 complete None
#  [*                 3%                  ]  355 of 13616 complete None
#  [*                 3%                  ]  356 of 13616 complete None
#  [*                 3%                  ]  357 of 13616 complete None
#  [*                 3%                  ]  358 of 13616 complete None
#  [*                 3%                  ]  359 of 13616 complete None
#  [*                 3%                  ]  360 of 13616 complete None
#  [*                 3%                  ]  361 of 13616 complete None
#  [*                 3%                  ]  362 of 13616 complete None
#  [*                 3%                  ]  363 of 13616 complete None
#  [*                 3%                  ]  364 of 13616 complete None
#  [*                 3%                  ]  365 of 13616 complete None
#  [*                 3%                  ]  366 of 13616 complete None
#  [*                 3%                  ]  367 of 13616 complete None
#  [*                 3%                  ]  368 of 13616 complete None
#  [*                 3%                  ]  369 of 13616 complete None
#  [*                 3%                  ]  370 of 13616 complete None
#  [*                 3%                  ]  371 of 13616 complete None
#  [*                 3%                  ]  372 of 13616 complete None
#  [*                 3%                  ]  373 of 13616 complete None
#  [*                 3%                  ]  374 of 13616 complete None
#  [*                 3%                  ]  375 of 13616 complete None
#  [*                 3%                  ]  376 of 13616 complete None
#  [*                 3%                  ]  377 of 13616 complete None
#  [*                 3%                  ]  378 of 13616 complete None
#  [*                 3%                  ]  379 of 13616 complete None
#  [*                 3%                  ]  380 of 13616 complete None
#  [*                 3%                  ]  381 of 13616 complete None
#  [*                 3%                  ]  382 of 13616 complete None
#  [*                 3%                  ]  383 of 13616 complete None
#  [*                 3%                  ]  384 of 13616 complete None
#  [*                 3%                  ]  385 of 13616 complete None
#  [*                 3%                  ]  386 of 13616 complete None
#  [*                 3%                  ]  387 of 13616 complete None
#  [*                 3%                  ]  388 of 13616 complete None
#  [*                 3%                  ]  389 of 13616 complete None
#  [*                 3%                  ]  390 of 13616 complete None
#  [*                 3%                  ]  391 of 13616 complete None
#  [*                 3%                  ]  392 of 13616 complete None
#  [*                 3%                  ]  393 of 13616 complete None
#  [*                 3%                  ]  394 of 13616 complete None
#  [*                 3%                  ]  395 of 13616 complete None
#  [*                 3%                  ]  396 of 13616 complete None
#  [*                 3%                  ]  397 of 13616 complete None
#  [*                 3%                  ]  398 of 13616 complete None
#  [*                 3%                  ]  399 of 13616 complete None
#  [*                 3%                  ]  400 of 13616 complete None
#  [*                 3%                  ]  401 of 13616 complete None
#  [*                 3%                  ]  402 of 13616 complete None
#  [*                 3%                  ]  403 of 13616 complete None
#  [*                 3%                  ]  404 of 13616 complete None
#  [*                 3%                  ]  405 of 13616 complete None
#  [*                 3%                  ]  406 of 13616 complete None
#  [*                 3%                  ]  407 of 13616 complete None
#  [*                 3%                  ]  408 of 13616 complete None
#  [*                 3%                  ]  409 of 13616 complete None
#  [*                 3%                  ]  410 of 13616 complete None
#  [*                 3%                  ]  411 of 13616 complete None
#  [*                 3%                  ]  412 of 13616 complete None
#  [*                 3%                  ]  413 of 13616 complete None
#  [*                 3%                  ]  414 of 13616 complete None
#  [*                 3%                  ]  415 of 13616 complete None
#  [*                 3%                  ]  416 of 13616 complete None
#  [*                 3%                  ]  417 of 13616 complete None
#  [*                 3%                  ]  418 of 13616 complete None
#  [*                 3%                  ]  419 of 13616 complete None
#  [*                 3%                  ]  420 of 13616 complete None
#  [*                 3%                  ]  421 of 13616 complete None
#  [*                 3%                  ]  422 of 13616 complete None
#  [*                 3%                  ]  423 of 13616 complete None
#  [*                 3%                  ]  424 of 13616 complete None
#  [*                 3%                  ]  425 of 13616 complete None
#  [*                 3%                  ]  426 of 13616 complete None
#  [*                 3%                  ]  427 of 13616 complete None
#  [*                 3%                  ]  428 of 13616 complete None
#  [*                 3%                  ]  429 of 13616 complete None
#  [*                 3%                  ]  430 of 13616 complete None
#  [*                 3%                  ]  431 of 13616 complete None
#  [*                 3%                  ]  432 of 13616 complete None
#  [*                 3%                  ]  433 of 13616 complete None
#  [*                 3%                  ]  434 of 13616 complete None
#  [*                 3%                  ]  435 of 13616 complete None
#  [*                 3%                  ]  436 of 13616 complete None
#  [*                 3%                  ]  437 of 13616 complete None
#  [*                 3%                  ]  438 of 13616 complete None
#  [*                 3%                  ]  439 of 13616 complete None
#  [*                 3%                  ]  440 of 13616 complete None
#  [*                 3%                  ]  441 of 13616 complete None
#  [*                 3%                  ]  442 of 13616 complete None
#  [*                 3%                  ]  443 of 13616 complete None
#  [*                 3%                  ]  444 of 13616 complete None
#  [*                 3%                  ]  445 of 13616 complete None
#  [*                 3%                  ]  446 of 13616 complete None
#  [*                 3%                  ]  447 of 13616 complete None
#  [*                 3%                  ]  448 of 13616 complete None
#  [*                 3%                  ]  449 of 13616 complete None
#  [*                 3%                  ]  450 of 13616 complete None
#  [*                 3%                  ]  451 of 13616 complete None
#  [*                 3%                  ]  452 of 13616 complete None
#  [*                 3%                  ]  453 of 13616 complete None
#  [*                 3%                  ]  454 of 13616 complete None
#  [*                 3%                  ]  455 of 13616 complete None
#  [*                 3%                  ]  456 of 13616 complete None
#  [*                 3%                  ]  457 of 13616 complete None
#  [*                 3%                  ]  458 of 13616 complete None
#  [*                 3%                  ]  459 of 13616 complete None
#  [*                 3%                  ]  460 of 13616 complete None
#  [*                 3%                  ]  461 of 13616 complete None
#  [*                 3%                  ]  462 of 13616 complete None
#  [*                 3%                  ]  463 of 13616 complete None
#  [*                 3%                  ]  464 of 13616 complete None
#  [*                 3%                  ]  465 of 13616 complete None
#  [*                 3%                  ]  466 of 13616 complete None
#  [*                 3%                  ]  467 of 13616 complete None
#  [*                 3%                  ]  468 of 13616 complete None
#  [*                 3%                  ]  469 of 13616 complete None
#  [*                 3%                  ]  470 of 13616 complete None
#  [*                 3%                  ]  471 of 13616 complete None
#  [*                 3%                  ]  472 of 13616 complete None
#  [*                 3%                  ]  473 of 13616 complete None
#  [*                 3%                  ]  474 of 13616 complete None
#  [*                 3%                  ]  475 of 13616 complete None
#  [*                 3%                  ]  476 of 13616 complete None
#  [**                4%                  ]  477 of 13616 complete None
#  [**                4%                  ]  478 of 13616 complete None
#  [**                4%                  ]  479 of 13616 complete None
#  [**                4%                  ]  480 of 13616 complete None
#  [**                4%                  ]  481 of 13616 complete None
#  [**                4%                  ]  482 of 13616 complete None
#  [**                4%                  ]  483 of 13616 complete None
#  [**                4%                  ]  484 of 13616 complete None
#  [**                4%                  ]  485 of 13616 complete None
#  [**                4%                  ]  486 of 13616 complete None
#  [**                4%                  ]  487 of 13616 complete None
#  [**                4%                  ]  488 of 13616 complete None
#  [**                4%                  ]  489 of 13616 complete None
#  [**                4%                  ]  490 of 13616 complete None
#  [**                4%                  ]  491 of 13616 complete None
#  [**                4%                  ]  492 of 13616 complete None
#  [**                4%                  ]  493 of 13616 complete None
#  [**                4%                  ]  494 of 13616 complete None
#  [**                4%                  ]  495 of 13616 complete None
#  [**                4%                  ]  496 of 13616 complete None
#  [**                4%                  ]  497 of 13616 complete None
#  [**                4%                  ]  498 of 13616 complete None
#  [**                4%                  ]  499 of 13616 complete None
#  [**                4%                  ]  500 of 13616 complete None
#  [**                4%                  ]  501 of 13616 complete None
#  [**                4%                  ]  502 of 13616 complete None
#  [**                4%                  ]  503 of 13616 complete None
#  [**                4%                  ]  504 of 13616 complete None
#  [**                4%                  ]  505 of 13616 complete None
#  [**                4%                  ]  506 of 13616 complete None
#  [**                4%                  ]  507 of 13616 complete None
#  [**                4%                  ]  508 of 13616 complete None
#  [**                4%                  ]  509 of 13616 complete None
#  [**                4%                  ]  510 of 13616 complete None
#  [**                4%                  ]  511 of 13616 complete None
#  [**                4%                  ]  512 of 13616 complete None
#  [**                4%                  ]  513 of 13616 complete None
#  [**                4%                  ]  514 of 13616 complete None
#  [**                4%                  ]  515 of 13616 complete None
#  [**                4%                  ]  516 of 13616 complete None
#  [**                4%                  ]  517 of 13616 complete None
#  [**                4%                  ]  518 of 13616 complete None
#  [**                4%                  ]  519 of 13616 complete None
#  [**                4%                  ]  520 of 13616 complete None
#  [**                4%                  ]  521 of 13616 complete None
#  [**                4%                  ]  522 of 13616 complete None
#  [**                4%                  ]  523 of 13616 complete None
#  [**                4%                  ]  524 of 13616 complete None
#  [**                4%                  ]  525 of 13616 complete None
#  [**                4%                  ]  526 of 13616 complete None
#  [**                4%                  ]  527 of 13616 complete None
#  [**                4%                  ]  528 of 13616 complete None
#  [**                4%                  ]  529 of 13616 complete None
#  [**                4%                  ]  530 of 13616 complete None
#  [**                4%                  ]  531 of 13616 complete None
#  [**                4%                  ]  532 of 13616 complete None
#  [**                4%                  ]  533 of 13616 complete None
#  [**                4%                  ]  534 of 13616 complete None
#  [**                4%                  ]  535 of 13616 complete None
#  [**                4%                  ]  536 of 13616 complete None
#  [**                4%                  ]  537 of 13616 complete None
#  [**                4%                  ]  538 of 13616 complete None
#  [**                4%                  ]  539 of 13616 complete None
#  [**                4%                  ]  540 of 13616 complete None
#  [**                4%                  ]  541 of 13616 complete None
#  [**                4%                  ]  542 of 13616 complete None
#  [**                4%                  ]  543 of 13616 complete None
#  [**                4%                  ]  544 of 13616 complete None
#  [**                4%                  ]  545 of 13616 complete None
#  [**                4%                  ]  546 of 13616 complete None
#  [**                4%                  ]  547 of 13616 complete None
#  [**                4%                  ]  548 of 13616 complete None
#  [**                4%                  ]  549 of 13616 complete None
#  [**                4%                  ]  550 of 13616 complete None
#  [**                4%                  ]  551 of 13616 complete None
#  [**                4%                  ]  552 of 13616 complete None
#  [**                4%                  ]  553 of 13616 complete None
#  [**                4%                  ]  554 of 13616 complete None
#  [**                4%                  ]  555 of 13616 complete None
#  [**                4%                  ]  556 of 13616 complete None
#  [**                4%                  ]  557 of 13616 complete None
#  [**                4%                  ]  558 of 13616 complete None
#  [**                4%                  ]  559 of 13616 complete None
#  [**                4%                  ]  560 of 13616 complete None
#  [**                4%                  ]  561 of 13616 complete None
#  [**                4%                  ]  562 of 13616 complete None
#  [**                4%                  ]  563 of 13616 complete None
#  [**                4%                  ]  564 of 13616 complete None
#  [**                4%                  ]  565 of 13616 complete None
#  [**                4%                  ]  566 of 13616 complete None
#  [**                4%                  ]  567 of 13616 complete None
#  [**                4%                  ]  568 of 13616 complete None
#  [**                4%                  ]  569 of 13616 complete None
#  [**                4%                  ]  570 of 13616 complete None
#  [**                4%                  ]  571 of 13616 complete None
#  [**                4%                  ]  572 of 13616 complete None
#  [**                4%                  ]  573 of 13616 complete None
#  [**                4%                  ]  574 of 13616 complete None
#  [**                4%                  ]  575 of 13616 complete None
#  [**                4%                  ]  576 of 13616 complete None
#  [**                4%                  ]  577 of 13616 complete None
#  [**                4%                  ]  578 of 13616 complete None
#  [**                4%                  ]  579 of 13616 complete None
#  [**                4%                  ]  580 of 13616 complete None
#  [**                4%                  ]  581 of 13616 complete None
#  [**                4%                  ]  582 of 13616 complete None
#  [**                4%                  ]  583 of 13616 complete None
#  [**                4%                  ]  584 of 13616 complete None
#  [**                4%                  ]  585 of 13616 complete None
#  [**                4%                  ]  586 of 13616 complete None
#  [**                4%                  ]  587 of 13616 complete None
#  [**                4%                  ]  588 of 13616 complete None
#  [**                4%                  ]  589 of 13616 complete None
#  [**                4%                  ]  590 of 13616 complete None
#  [**                4%                  ]  591 of 13616 complete None
#  [**                4%                  ]  592 of 13616 complete None
#  [**                4%                  ]  593 of 13616 complete None
#  [**                4%                  ]  594 of 13616 complete None
#  [**                4%                  ]  595 of 13616 complete None
#  [**                4%                  ]  596 of 13616 complete None
#  [**                4%                  ]  597 of 13616 complete None
#  [**                4%                  ]  598 of 13616 complete None
#  [**                4%                  ]  599 of 13616 complete None
#  [**                4%                  ]  600 of 13616 complete None
#  [**                4%                  ]  601 of 13616 complete None
#  [**                4%                  ]  602 of 13616 complete None
#  [**                4%                  ]  603 of 13616 complete None
#  [**                4%                  ]  604 of 13616 complete None
#  [**                4%                  ]  605 of 13616 complete None
#  [**                4%                  ]  606 of 13616 complete None
#  [**                4%                  ]  607 of 13616 complete None
#  [**                4%                  ]  608 of 13616 complete None
#  [**                4%                  ]  609 of 13616 complete None
#  [**                4%                  ]  610 of 13616 complete None
#  [**                4%                  ]  611 of 13616 complete None
#  [**                4%                  ]  612 of 13616 complete None
#  [**                5%                  ]  613 of 13616 complete None
#  [**                5%                  ]  614 of 13616 complete None
#  [**                5%                  ]  615 of 13616 complete None
#  [**                5%                  ]  616 of 13616 complete None
#  [**                5%                  ]  617 of 13616 complete None
#  [**                5%                  ]  618 of 13616 complete None
#  [**                5%                  ]  619 of 13616 complete None
#  [**                5%                  ]  620 of 13616 complete None
#  [**                5%                  ]  621 of 13616 complete None
#  [**                5%                  ]  622 of 13616 complete None
#  [**                5%                  ]  623 of 13616 complete None
#  [**                5%                  ]  624 of 13616 complete None
#  [**                5%                  ]  625 of 13616 complete None
#  [**                5%                  ]  626 of 13616 complete None
#  [**                5%                  ]  627 of 13616 complete None
#  [**                5%                  ]  628 of 13616 complete None
#  [**                5%                  ]  629 of 13616 complete None
#  [**                5%                  ]  630 of 13616 complete None
#  [**                5%                  ]  631 of 13616 complete None
#  [**                5%                  ]  632 of 13616 complete None
#  [**                5%                  ]  633 of 13616 complete None
#  [**                5%                  ]  634 of 13616 complete None
#  [**                5%                  ]  635 of 13616 complete None
#  [**                5%                  ]  636 of 13616 complete None
#  [**                5%                  ]  637 of 13616 complete None
#  [**                5%                  ]  638 of 13616 complete None
#  [**                5%                  ]  639 of 13616 complete None
#  [**                5%                  ]  640 of 13616 complete None
#  [**                5%                  ]  641 of 13616 complete None
#  [**                5%                  ]  642 of 13616 complete None
#  [**                5%                  ]  643 of 13616 complete None
#  [**                5%                  ]  644 of 13616 complete None
#  [**                5%                  ]  645 of 13616 complete None
#  [**                5%                  ]  646 of 13616 complete None
#  [**                5%                  ]  647 of 13616 complete None
#  [**                5%                  ]  648 of 13616 complete None
#  [**                5%                  ]  649 of 13616 complete None
#  [**                5%                  ]  650 of 13616 complete None
#  [**                5%                  ]  651 of 13616 complete None
#  [**                5%                  ]  652 of 13616 complete None
#  [**                5%                  ]  653 of 13616 complete None
#  [**                5%                  ]  654 of 13616 complete None
#  [**                5%                  ]  655 of 13616 complete None
#  [**                5%                  ]  656 of 13616 complete None
#  [**                5%                  ]  657 of 13616 complete None
#  [**                5%                  ]  658 of 13616 complete None
#  [**                5%                  ]  659 of 13616 complete None
#  [**                5%                  ]  660 of 13616 complete None
#  [**                5%                  ]  661 of 13616 complete None
#  [**                5%                  ]  662 of 13616 complete None
#  [**                5%                  ]  663 of 13616 complete None
#  [**                5%                  ]  664 of 13616 complete None
#  [**                5%                  ]  665 of 13616 complete None
#  [**                5%                  ]  666 of 13616 complete None
#  [**                5%                  ]  667 of 13616 complete None
#  [**                5%                  ]  668 of 13616 complete None
#  [**                5%                  ]  669 of 13616 complete None
#  [**                5%                  ]  670 of 13616 complete None
#  [**                5%                  ]  671 of 13616 complete None
#  [**                5%                  ]  672 of 13616 complete None
#  [**                5%                  ]  673 of 13616 complete None
#  [**                5%                  ]  674 of 13616 complete None
#  [**                5%                  ]  675 of 13616 complete None
#  [**                5%                  ]  676 of 13616 complete None
#  [**                5%                  ]  677 of 13616 complete None
#  [**                5%                  ]  678 of 13616 complete None
#  [**                5%                  ]  679 of 13616 complete None
#  [**                5%                  ]  680 of 13616 complete None
#  [**                5%                  ]  681 of 13616 complete None
#  [**                5%                  ]  682 of 13616 complete None
#  [**                5%                  ]  683 of 13616 complete None
#  [**                5%                  ]  684 of 13616 complete None
#  [**                5%                  ]  685 of 13616 complete None
#  [**                5%                  ]  686 of 13616 complete None
#  [**                5%                  ]  687 of 13616 complete None
# ...
#  [*****************98%***************** ]  13402 of 13616 complete None
#  [*****************98%***************** ]  13403 of 13616 complete None
#  [*****************98%***************** ]  13404 of 13616 complete None
#  [*****************98%***************** ]  13405 of 13616 complete None
#  [*****************98%***************** ]  13406 of 13616 complete None
#  [*****************98%***************** ]  13407 of 13616 complete None
#  [*****************98%***************** ]  13408 of 13616 complete None
#  [*****************98%***************** ]  13409 of 13616 complete None
#  [*****************98%***************** ]  13410 of 13616 complete None
#  [*****************98%***************** ]  13411 of 13616 complete None
#  [*****************99%******************]  13412 of 13616 complete None
#  [*****************99%******************]  13413 of 13616 complete None
#  [*****************99%******************]  13414 of 13616 complete None
#  [*****************99%******************]  13415 of 13616 complete None
#  [*****************99%******************]  13416 of 13616 complete None
#  [*****************99%******************]  13417 of 13616 complete None
#  [*****************99%******************]  13418 of 13616 complete None
#  [*****************99%******************]  13419 of 13616 complete None
#  [*****************99%******************]  13420 of 13616 complete None
#  [*****************99%******************]  13421 of 13616 complete None
#  [*****************99%******************]  13422 of 13616 complete None
#  [*****************99%******************]  13423 of 13616 complete None
#  [*****************99%******************]  13424 of 13616 complete None
#  [*****************99%******************]  13425 of 13616 complete None
#  [*****************99%******************]  13426 of 13616 complete None
#  [*****************99%******************]  13427 of 13616 complete None
#  [*****************99%******************]  13428 of 13616 complete None
#  [*****************99%******************]  13429 of 13616 complete None
#  [*****************99%******************]  13430 of 13616 complete None
#  [*****************99%******************]  13431 of 13616 complete None
#  [*****************99%******************]  13432 of 13616 complete None
#  [*****************99%******************]  13433 of 13616 complete None
#  [*****************99%******************]  13434 of 13616 complete None
#  [*****************99%******************]  13435 of 13616 complete None
#  [*****************99%******************]  13436 of 13616 complete None
#  [*****************99%******************]  13437 of 13616 complete None
#  [*****************99%******************]  13438 of 13616 complete None
#  [*****************99%******************]  13439 of 13616 complete None
#  [*****************99%******************]  13440 of 13616 complete None
#  [*****************99%******************]  13441 of 13616 complete None
#  [*****************99%******************]  13442 of 13616 complete None
#  [*****************99%******************]  13443 of 13616 complete None
#  [*****************99%******************]  13444 of 13616 complete None
#  [*****************99%******************]  13445 of 13616 complete None
#  [*****************99%******************]  13446 of 13616 complete None
#  [*****************99%******************]  13447 of 13616 complete None
#  [*****************99%******************]  13448 of 13616 complete None
#  [*****************99%******************]  13449 of 13616 complete None
#  [*****************99%******************]  13450 of 13616 complete None
#  [*****************99%******************]  13451 of 13616 complete None
#  [*****************99%******************]  13452 of 13616 complete None
#  [*****************99%******************]  13453 of 13616 complete None
#  [*****************99%******************]  13454 of 13616 complete None
#  [*****************99%******************]  13455 of 13616 complete None
#  [*****************99%******************]  13456 of 13616 complete None
#  [*****************99%******************]  13457 of 13616 complete None
#  [*****************99%******************]  13458 of 13616 complete None
#  [*****************99%******************]  13459 of 13616 complete None
#  [*****************99%******************]  13460 of 13616 complete None
#  [*****************99%******************]  13461 of 13616 complete None
#  [*****************99%******************]  13462 of 13616 complete None
#  [*****************99%******************]  13463 of 13616 complete None
#  [*****************99%******************]  13464 of 13616 complete None
#  [*****************99%******************]  13465 of 13616 complete None
#  [*****************99%******************]  13466 of 13616 complete None
#  [*****************99%******************]  13467 of 13616 complete None
#  [*****************99%******************]  13468 of 13616 complete None
#  [*****************99%******************]  13469 of 13616 complete None
#  [*****************99%******************]  13470 of 13616 complete None
#  [*****************99%******************]  13471 of 13616 complete None
#  [*****************99%******************]  13472 of 13616 complete None
#  [*****************99%******************]  13473 of 13616 complete None
#  [*****************99%******************]  13474 of 13616 complete None
#  [*****************99%******************]  13475 of 13616 complete None
#  [*****************99%******************]  13476 of 13616 complete None
#  [*****************99%******************]  13477 of 13616 complete None
#  [*****************99%******************]  13478 of 13616 complete None
#  [*****************99%******************]  13479 of 13616 complete None
#  [*****************99%******************]  13480 of 13616 complete None
#  [*****************99%******************]  13481 of 13616 complete None
#  [*****************99%******************]  13482 of 13616 complete None
#  [*****************99%******************]  13483 of 13616 complete None
#  [*****************99%******************]  13484 of 13616 complete None
#  [*****************99%******************]  13485 of 13616 complete None
#  [*****************99%******************]  13486 of 13616 complete None
#  [*****************99%******************]  13487 of 13616 complete None
#  [*****************99%******************]  13488 of 13616 complete None
#  [*****************99%******************]  13489 of 13616 complete None
#  [*****************99%******************]  13490 of 13616 complete None
#  [*****************99%******************]  13491 of 13616 complete None
#  [*****************99%******************]  13492 of 13616 complete None
#  [*****************99%******************]  13493 of 13616 complete None
#  [*****************99%******************]  13494 of 13616 complete None
#  [*****************99%******************]  13495 of 13616 complete None
#  [*****************99%******************]  13496 of 13616 complete None
#  [*****************99%******************]  13497 of 13616 complete None
#  [*****************99%******************]  13498 of 13616 complete None
#  [*****************99%******************]  13499 of 13616 complete None
#  [*****************99%******************]  13500 of 13616 complete None
#  [*****************99%******************]  13501 of 13616 complete None
#  [*****************99%******************]  13502 of 13616 complete None
#  [*****************99%******************]  13503 of 13616 complete None
#  [*****************99%******************]  13504 of 13616 complete None
#  [*****************99%******************]  13505 of 13616 complete None
#  [*****************99%******************]  13506 of 13616 complete None
#  [*****************99%******************]  13507 of 13616 complete None
#  [*****************99%******************]  13508 of 13616 complete None
#  [*****************99%******************]  13509 of 13616 complete None
#  [*****************99%******************]  13510 of 13616 complete None
#  [*****************99%******************]  13511 of 13616 complete None
#  [*****************99%******************]  13512 of 13616 complete None
#  [*****************99%******************]  13513 of 13616 complete None
#  [*****************99%******************]  13514 of 13616 complete None
#  [*****************99%******************]  13515 of 13616 complete None
#  [*****************99%******************]  13516 of 13616 complete None
#  [*****************99%******************]  13517 of 13616 complete None
#  [*****************99%******************]  13518 of 13616 complete None
#  [*****************99%******************]  13519 of 13616 complete None
#  [*****************99%******************]  13520 of 13616 complete None
#  [*****************99%******************]  13521 of 13616 complete None
#  [*****************99%******************]  13522 of 13616 complete None
#  [*****************99%******************]  13523 of 13616 complete None
#  [*****************99%******************]  13524 of 13616 complete None
#  [*****************99%******************]  13525 of 13616 complete None
#  [*****************99%******************]  13526 of 13616 complete None
#  [*****************99%******************]  13527 of 13616 complete None
#  [*****************99%******************]  13528 of 13616 complete None
#  [*****************99%******************]  13529 of 13616 complete None
#  [*****************99%******************]  13530 of 13616 complete None
#  [*****************99%******************]  13531 of 13616 complete None
#  [*****************99%******************]  13532 of 13616 complete None
#  [*****************99%******************]  13533 of 13616 complete None
#  [*****************99%******************]  13534 of 13616 complete None
#  [*****************99%******************]  13535 of 13616 complete None
#  [*****************99%******************]  13536 of 13616 complete None
#  [*****************99%******************]  13537 of 13616 complete None
#  [*****************99%******************]  13538 of 13616 complete None
#  [*****************99%******************]  13539 of 13616 complete None
#  [*****************99%******************]  13540 of 13616 complete None
#  [*****************99%******************]  13541 of 13616 complete None
#  [*****************99%******************]  13542 of 13616 complete None
#  [*****************99%******************]  13543 of 13616 complete None
#  [*****************99%******************]  13544 of 13616 complete None
#  [*****************99%******************]  13545 of 13616 complete None
#  [*****************99%******************]  13546 of 13616 complete None
#  [*****************99%******************]  13547 of 13616 complete None
#  [****************100%******************]  13548 of 13616 complete None
#  [****************100%******************]  13549 of 13616 complete None
#  [****************100%******************]  13550 of 13616 complete None
#  [****************100%******************]  13551 of 13616 complete None
#  [****************100%******************]  13552 of 13616 complete None
#  [****************100%******************]  13553 of 13616 complete None
#  [****************100%******************]  13554 of 13616 complete None
#  [****************100%******************]  13555 of 13616 complete None
#  [****************100%******************]  13556 of 13616 complete None
#  [****************100%******************]  13557 of 13616 complete None
#  [****************100%******************]  13558 of 13616 complete None
#  [****************100%******************]  13559 of 13616 complete None
#  [****************100%******************]  13560 of 13616 complete None
#  [****************100%******************]  13561 of 13616 complete None
#  [****************100%******************]  13562 of 13616 complete None
#  [****************100%******************]  13563 of 13616 complete None
#  [****************100%******************]  13564 of 13616 complete None
#  [****************100%******************]  13565 of 13616 complete None
#  [****************100%******************]  13566 of 13616 complete None
#  [****************100%******************]  13567 of 13616 complete None
#  [****************100%******************]  13568 of 13616 complete None
#  [****************100%******************]  13569 of 13616 complete None
#  [****************100%******************]  13570 of 13616 complete None
#  [****************100%******************]  13571 of 13616 complete None
#  [****************100%******************]  13572 of 13616 complete None
#  [****************100%******************]  13573 of 13616 complete None
#  [****************100%******************]  13574 of 13616 complete None
#  [****************100%******************]  13575 of 13616 complete None
#  [****************100%******************]  13576 of 13616 complete None
#  [****************100%******************]  13577 of 13616 complete None
#  [****************100%******************]  13578 of 13616 complete None
#  [****************100%******************]  13579 of 13616 complete None
#  [****************100%******************]  13580 of 13616 complete None
#  [****************100%******************]  13581 of 13616 complete None
#  [****************100%******************]  13582 of 13616 complete None
#  [****************100%******************]  13583 of 13616 complete None
#  [****************100%******************]  13584 of 13616 complete None
#  [****************100%******************]  13585 of 13616 complete None
#  [****************100%******************]  13586 of 13616 complete None
#  [****************100%******************]  13587 of 13616 complete None
#  [****************100%******************]  13588 of 13616 complete None
#  [****************100%******************]  13589 of 13616 complete None
#  [****************100%******************]  13590 of 13616 complete None
#  [****************100%******************]  13591 of 13616 complete None
#  [****************100%******************]  13592 of 13616 complete None
#  [****************100%******************]  13593 of 13616 complete None
#  [****************100%******************]  13594 of 13616 complete None
#  [****************100%******************]  13595 of 13616 complete None
#  [****************100%******************]  13596 of 13616 complete None
#  [****************100%******************]  13597 of 13616 complete None
#  [****************100%******************]  13598 of 13616 complete None
#  [****************100%******************]  13599 of 13616 complete None
#  [****************100%******************]  13600 of 13616 complete None
#  [****************100%******************]  13601 of 13616 complete None
#  [****************100%******************]  13602 of 13616 complete None
#  [****************100%******************]  13603 of 13616 complete None
#  [****************100%******************]  13604 of 13616 complete None
#  [****************100%******************]  13605 of 13616 complete None
#  [****************100%******************]  13606 of 13616 complete None
#  [****************100%******************]  13607 of 13616 complete None
#  [****************100%******************]  13608 of 13616 complete None
#  [****************100%******************]  13609 of 13616 complete None
#  [****************100%******************]  13610 of 13616 complete None
#  [****************100%******************]  13611 of 13616 complete None
#  [****************100%******************]  13612 of 13616 complete None
#  [****************100%******************]  13613 of 13616 complete None
#  [****************100%******************]  13614 of 13616 complete None
#  [****************100%******************]  13615 of 13616 complete None
#  [****************100%******************]  13616 of 13616 complete None
# C:\Users\aikyn\AppData\Local\Temp\ipykernel_6220\3586895474.py:183: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_data = mode(knn_labels, axis=1)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(label, y_test[::num],target_names=[l for l in labels.values()]))

conf_mat = confusion_matrix(label, y_test[::num])

fig = plt.figure(figsize=(6,6))
width = np.shape(conf_mat)[1]
height = np.shape(conf_mat)[0]

res = plt.imshow(np.array(conf_mat), cmap=plt.cm.summer, interpolation='nearest')
for i, row in enumerate(conf_mat):
    for j, c in enumerate(row):
        if c>0:
            plt.text(j-.2, i+.1, c, fontsize=16)
            
cb = fig.colorbar(res)
plt.title('Confusion Matrix')
_ = plt.xticks(range(6), [l for l in labels.values()], rotation=90)
_ = plt.yticks(range(6), [l for l in labels.values()])
# Out:
#                     precision    recall  f1-score   support
#
#            WALKING       0.64      0.64      0.64        11
#   WALKING UPSTAIRS       0.86      0.86      0.86        14
# WALKING DOWNSTAIRS       0.64      0.64      0.64        11
#            SITTING       0.33      0.27      0.30        15
#           STANDING       0.17      0.18      0.17        11
#             LAYING       0.29      0.33      0.31        12
#
#           accuracy                           0.49        74
#          macro avg       0.49      0.49      0.48        74
#       weighted avg       0.49      0.49      0.49        74
# C:\Users\aikyn\AppData\Local\Temp\ipykernel_6220\2341433299.py:16: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = fig.colorbar(res)
